# %%
from PIL import Image
from PIL import ImageDraw
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#test on image number 43 for male 15 years old
r_image=Image.open("/content/43-15M_crop.jpg")
draw = ImageDraw.Draw(r_image)
draw.line((330,465,266,366), fill='black', width=2)
draw.line((350,450,367,430), fill='black', width=2)
draw.line((308,485,323,470), fill='black', width=2)
plt.imshow(r_image)

# %%
v= 0.08221083073205848 #pixel density 
dif1 = abs(complex(330,465) - complex(266,366))
dif2 = abs(complex(350,450) - complex(367,430))
dif3 = abs(complex(308,485) - complex(323,470))

l=dif1*v
d=dif2*v
m=dif3*v
print('\n','length=',l,'\n','distal=',d,'\n','mesial=',m)

total= (d+m)/l
print('\n','I3m=',total)
# Out:
#  length= 9.691467986024508
#  distal= 2.1579364344605736
#  mesial= 1.7439550769285392
#
#  I3m= 0.4026109890695403
